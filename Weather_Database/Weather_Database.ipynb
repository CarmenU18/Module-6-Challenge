# %% [markdown]
# ### Deliverable 1

# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the citipy module
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime
import json

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9546d9c3da4a> in <module>
# ----> 1 city_weather = requests.get(city_url).json()
#       2 city_weather
#
# NameError: name 'city_url' is not defined

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tanquian
# City not found. Skipping...
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | saint george
# Processing Record 4 of Set 1 | coahuayana
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | salalah
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | saint-pierre
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | mutis
# Processing Record 15 of Set 1 | coracao de jesus
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | unye
# City not found. Skipping...
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | manokwari
# Processing Record 22 of Set 1 | nishihara
# Processing Record 23 of Set 1 | sal rei
# Processing Record 24 of Set 1 | grand gaube
# Processing Record 25 of Set 1 | ostrovnoy
# Processing Record 26 of Set 1 | havre-saint-pierre
# Processing Record 27 of Set 1 | emerald
# Processing Record 28 of Set 1 | birao
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | lata
# Processing Record 33 of Set 1 | tabuk
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | ende
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | nanning
# Processing Record 39 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 1 | vardo
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 1 | marawi
# Processing Record 44 of Set 1 | orocue
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | lorengau
# Processing Record 47 of Set 1 | san luis
# Processing Record 48 of Set 1 | uyaan
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | dunedin
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | yavatmal
# Processing Record 7 of Set 2 | bukama
# Processing Record 8 of Set 2 | beitbridge
# Processing Record 9 of Set 2 | husavik
# Processing Record 10 of Set 2 | kant
# Processing Record 11 of Set 2 | aketi
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | yangjiang
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | solnechnyy
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | guerrero negro
# Processing Record 20 of Set 2 | cidreira
# Processing Record 21 of Set 2 | zhongshu
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | vostok
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | vila
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | bara
# Processing Record 29 of Set 2 | labuhan
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | charters towers
# Processing Record 33 of Set 2 | geraldton
# Processing Record 34 of Set 2 | puquio
# Processing Record 35 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 2 | yumen
# Processing Record 37 of Set 2 | porto novo
# Processing Record 38 of Set 2 | cockburn town
# Processing Record 39 of Set 2 | carupano
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | union city
# Processing Record 42 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 2 | katsuura
# Processing Record 44 of Set 2 | inirida
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | smithers
# Processing Record 48 of Set 2 | souillac
# Processing Record 49 of Set 2 | rawah
# Processing Record 50 of Set 2 | kayerkan
# Processing Record 1 of Set 3 | cap-aux-meules
# Processing Record 2 of Set 3 | balangir
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | yago
# Processing Record 5 of Set 3 | touros
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | panama city
# Processing Record 8 of Set 3 | keta
# Processing Record 9 of Set 3 | kulmbach
# Processing Record 10 of Set 3 | myrtle beach
# Processing Record 11 of Set 3 | kulhudhuffushi
# Processing Record 12 of Set 3 | bilibino
# Processing Record 13 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | mahebourg
# Processing Record 16 of Set 3 | nuuk
# Processing Record 17 of Set 3 | norman wells
# Processing Record 18 of Set 3 | udachnyy
# Processing Record 19 of Set 3 | cochrane
# Processing Record 20 of Set 3 | inongo
# Processing Record 21 of Set 3 | luderitz
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | atuona
# Processing Record 24 of Set 3 | mbandaka
# Processing Record 25 of Set 3 | lompoc
# Processing Record 26 of Set 3 | sept-iles
# Processing Record 27 of Set 3 | brae
# Processing Record 28 of Set 3 | shingu
# Processing Record 29 of Set 3 | sungaipenuh
# Processing Record 30 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | zaltan
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | phangnga
# Processing Record 37 of Set 3 | ustka
# Processing Record 38 of Set 3 | te anau
# Processing Record 39 of Set 3 | amahai
# Processing Record 40 of Set 3 | ancud
# Processing Record 41 of Set 3 | kangaatsiaq
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 3 | faya
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | burica
# City not found. Skipping...
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | nantucket
# Processing Record 49 of Set 3 | berlevag
# Processing Record 50 of Set 3 | seoul
# Processing Record 1 of Set 4 | ouadda
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | yar-sale
# Processing Record 4 of Set 4 | bad doberan
# Processing Record 5 of Set 4 | jacareacanga
# Processing Record 6 of Set 4 | castrillon
# Processing Record 7 of Set 4 | mandera
# Processing Record 8 of Set 4 | poco verde
# Processing Record 9 of Set 4 | phalauda
# Processing Record 10 of Set 4 | eureka
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | hovd
# Processing Record 13 of Set 4 | baykit
# Processing Record 14 of Set 4 | chabahar
# Processing Record 15 of Set 4 | chifeng
# Processing Record 16 of Set 4 | palora
# Processing Record 17 of Set 4 | cape town
# Processing Record 18 of Set 4 | kalmunai
# Processing Record 19 of Set 4 | port elizabeth
# Processing Record 20 of Set 4 | vilhena
# Processing Record 21 of Set 4 | jurm
# Processing Record 22 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 4 | sakaiminato
# Processing Record 24 of Set 4 | tiarei
# Processing Record 25 of Set 4 | itapirapua
# Processing Record 26 of Set 4 | simao
# Processing Record 27 of Set 4 | portland
# Processing Record 28 of Set 4 | provideniya
# Processing Record 29 of Set 4 | kaeo
# Processing Record 30 of Set 4 | calbuco
# Processing Record 31 of Set 4 | khatanga
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | hervey bay
# Processing Record 34 of Set 4 | yulara
# Processing Record 35 of Set 4 | moose factory
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | vitim
# Processing Record 38 of Set 4 | green river
# Processing Record 39 of Set 4 | presidencia roque saenz pena
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | cabo san lucas
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | mayskiy
# Processing Record 45 of Set 4 | kisujszallas
# Processing Record 46 of Set 4 | patu
# Processing Record 47 of Set 4 | praia da vitoria
# Processing Record 48 of Set 4 | myanaung
# Processing Record 49 of Set 4 | huntsville
# Processing Record 50 of Set 4 | tuktoyaktuk
# Processing Record 1 of Set 5 | mamontovo
# Processing Record 2 of Set 5 | port hedland
# Processing Record 3 of Set 5 | ola
# Processing Record 4 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 5 | vila velha
# Processing Record 6 of Set 5 | kontagora
# Processing Record 7 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 5 | walvis bay
# Processing Record 9 of Set 5 | swan hill
# Processing Record 10 of Set 5 | fairbanks
# Processing Record 11 of Set 5 | kyzyl-suu
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | clyde river
# Processing Record 14 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 15 of Set 5 | grindavik
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | saint-francois
# Processing Record 18 of Set 5 | arman
# Processing Record 19 of Set 5 | ojinaga
# Processing Record 20 of Set 5 | hofn
# Processing Record 21 of Set 5 | margate
# Processing Record 22 of Set 5 | sabzevar
# Processing Record 23 of Set 5 | ulaanbaatar
# Processing Record 24 of Set 5 | alyangula
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | kagalnik
# Processing Record 27 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 5 | khvoynaya
# Processing Record 29 of Set 5 | umm lajj
# Processing Record 30 of Set 5 | ketchikan
# Processing Record 31 of Set 5 | kodinsk
# Processing Record 32 of Set 5 | tabou
# Processing Record 33 of Set 5 | marystown
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | sigli
# Processing Record 36 of Set 5 | mar del plata
# Processing Record 37 of Set 5 | padang
# Processing Record 38 of Set 5 | yerbogachen
# Processing Record 39 of Set 5 | freistadt
# Processing Record 40 of Set 5 | lagoa
# Processing Record 41 of Set 5 | tabas
# Processing Record 42 of Set 5 | esperance
# Processing Record 43 of Set 5 | calama
# Processing Record 44 of Set 5 | warrnambool
# Processing Record 45 of Set 5 | sokolo
# Processing Record 46 of Set 5 | rongotea
# Processing Record 47 of Set 5 | xining
# Processing Record 48 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 5 | kruisfontein
# Processing Record 50 of Set 5 | waddan
# Processing Record 1 of Set 6 | beipiao
# Processing Record 2 of Set 6 | ixtapa
# Processing Record 3 of Set 6 | bacolod
# Processing Record 4 of Set 6 | araouane
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | oistins
# Processing Record 7 of Set 6 | turukhansk
# Processing Record 8 of Set 6 | lipetsk
# Processing Record 9 of Set 6 | bar harbor
# Processing Record 10 of Set 6 | soyo
# Processing Record 11 of Set 6 | saquena
# Processing Record 12 of Set 6 | sisimiut
# Processing Record 13 of Set 6 | nabire
# Processing Record 14 of Set 6 | miyang
# Processing Record 15 of Set 6 | sitka
# Processing Record 16 of Set 6 | maningrida
# Processing Record 17 of Set 6 | ferme-neuve
# Processing Record 18 of Set 6 | victoria
# Processing Record 19 of Set 6 | matara
# Processing Record 20 of Set 6 | rio grande
# Processing Record 21 of Set 6 | vredendal
# Processing Record 22 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 6 | luanda
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 6 | araguacu
# Processing Record 27 of Set 6 | port lincoln
# Processing Record 28 of Set 6 | murray bridge
# Processing Record 29 of Set 6 | filingue
# Processing Record 30 of Set 6 | whitehorse
# Processing Record 31 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 6 | kahului
# Processing Record 33 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 6 | pevek
# Processing Record 35 of Set 6 | chicama
# Processing Record 36 of Set 6 | kampene
# Processing Record 37 of Set 6 | kavaratti
# Processing Record 38 of Set 6 | ormara
# Processing Record 39 of Set 6 | kapit
# Processing Record 40 of Set 6 | rundu
# Processing Record 41 of Set 6 | trenggalek
# Processing Record 42 of Set 6 | ordu
# Processing Record 43 of Set 6 | tulum
# Processing Record 44 of Set 6 | casper
# Processing Record 45 of Set 6 | basey
# Processing Record 46 of Set 6 | atar
# Processing Record 47 of Set 6 | hofu
# Processing Record 48 of Set 6 | aksu
# Processing Record 49 of Set 6 | naftalan
# Processing Record 50 of Set 6 | morehead
# Processing Record 1 of Set 7 | ruidoso
# Processing Record 2 of Set 7 | constitucion
# Processing Record 3 of Set 7 | sao paulo de olivenca
# Processing Record 4 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 5 of Set 7 | bonavista
# Processing Record 6 of Set 7 | boca do acre
# Processing Record 7 of Set 7 | buraydah
# Processing Record 8 of Set 7 | sao filipe
# Processing Record 9 of Set 7 | santiago del estero
# Processing Record 10 of Set 7 | kochubey
# Processing Record 11 of Set 7 | upernavik
# Processing Record 12 of Set 7 | bejar
# Processing Record 13 of Set 7 | teguldet
# Processing Record 14 of Set 7 | tuatapere
# Processing Record 15 of Set 7 | ulaangom
# Processing Record 16 of Set 7 | la ronge
# Processing Record 17 of Set 7 | rawson
# Processing Record 18 of Set 7 | vao
# Processing Record 19 of Set 7 | aller
# Processing Record 20 of Set 7 | tauranga
# Processing Record 21 of Set 7 | sao joao da barra
# Processing Record 22 of Set 7 | tanout
# Processing Record 23 of Set 7 | usoke
# Processing Record 24 of Set 7 | korgen
# Processing Record 25 of Set 7 | namatanai
# Processing Record 26 of Set 7 | saint-philippe
# Processing Record 27 of Set 7 | los llanos de aridane
# Processing Record 28 of Set 7 | alice springs
# Processing Record 29 of Set 7 | joensuu
# Processing Record 30 of Set 7 | insar
# Processing Record 31 of Set 7 | naze
# Processing Record 32 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 7 | bluefields
# Processing Record 34 of Set 7 | kerouane
# Processing Record 35 of Set 7 | mahanoro
# Processing Record 36 of Set 7 | moron
# Processing Record 37 of Set 7 | saldanha
# Processing Record 38 of Set 7 | fort morgan
# Processing Record 39 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 7 | hami
# Processing Record 41 of Set 7 | ankang
# Processing Record 42 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 7 | moses lake
# Processing Record 44 of Set 7 | celestun
# Processing Record 45 of Set 7 | tyshkivka
# Processing Record 46 of Set 7 | guanica
# Processing Record 47 of Set 7 | maceio
# Processing Record 48 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 7 | falam
# Processing Record 50 of Set 7 | coquimbo
# Processing Record 1 of Set 8 | nalut
# Processing Record 2 of Set 8 | coihaique
# Processing Record 3 of Set 8 | acoua
# Processing Record 4 of Set 8 | torbay
# Processing Record 5 of Set 8 | lavrentiya
# Processing Record 6 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 7 of Set 8 | necochea
# Processing Record 8 of Set 8 | beshpagir
# Processing Record 9 of Set 8 | bubaque
# Processing Record 10 of Set 8 | bellary
# Processing Record 11 of Set 8 | buchanan
# Processing Record 12 of Set 8 | mirabad
# Processing Record 13 of Set 8 | barguzin
# Processing Record 14 of Set 8 | malakal
# Processing Record 15 of Set 8 | longyearbyen
# Processing Record 16 of Set 8 | isangel
# Processing Record 17 of Set 8 | penalva
# Processing Record 18 of Set 8 | port-gentil
# Processing Record 19 of Set 8 | sao raimundo das mangabeiras
# Processing Record 20 of Set 8 | leeton
# Processing Record 21 of Set 8 | talnakh
# Processing Record 22 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 8 | tazovskiy
# Processing Record 24 of Set 8 | ribeira grande
# Processing Record 25 of Set 8 | waingapu
# Processing Record 26 of Set 8 | farsala
# Processing Record 27 of Set 8 | deputatskiy
# Processing Record 28 of Set 8 | laguna
# Processing Record 29 of Set 8 | fort-shevchenko
# Processing Record 30 of Set 8 | plyussa
# Processing Record 31 of Set 8 | arica
# Processing Record 32 of Set 8 | novyy urgal
# Processing Record 33 of Set 8 | humberto de campos
# Processing Record 34 of Set 8 | nome
# Processing Record 35 of Set 8 | port hardy
# Processing Record 36 of Set 8 | srikakulam
# Processing Record 37 of Set 8 | hambantota
# Processing Record 38 of Set 8 | masvingo
# Processing Record 39 of Set 8 | moerai
# Processing Record 40 of Set 8 | akdagmadeni
# Processing Record 41 of Set 8 | yenagoa
# Processing Record 42 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 8 | shimoda
# Processing Record 44 of Set 8 | tongliao
# Processing Record 45 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 8 | aswan
# Processing Record 47 of Set 8 | asau
# Processing Record 48 of Set 8 | galveston
# Processing Record 49 of Set 8 | zhoucheng
# Processing Record 50 of Set 8 | beloha
# Processing Record 1 of Set 9 | saint-denis
# Processing Record 2 of Set 9 | bereda
# Processing Record 3 of Set 9 | mount isa
# Processing Record 4 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 9 | hondo
# Processing Record 6 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 9 | vaitape
# Processing Record 8 of Set 9 | nelson bay
# Processing Record 9 of Set 9 | kandrian
# Processing Record 10 of Set 9 | dingle
# Processing Record 11 of Set 9 | vila franca do campo
# Processing Record 12 of Set 9 | couvin
# Processing Record 13 of Set 9 | batemans bay
# Processing Record 14 of Set 9 | kisanga
# Processing Record 15 of Set 9 | kununurra
# Processing Record 16 of Set 9 | cherskiy
# Processing Record 17 of Set 9 | thinadhoo
# Processing Record 18 of Set 9 | banes
# Processing Record 19 of Set 9 | lubana
# Processing Record 20 of Set 9 | aguimes
# Processing Record 21 of Set 9 | belaya gora
# Processing Record 22 of Set 9 | pangnirtung
# Processing Record 23 of Set 9 | sale
# Processing Record 24 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 9 | taltal
# Processing Record 26 of Set 9 | saint-georges
# Processing Record 27 of Set 9 | half moon bay
# Processing Record 28 of Set 9 | usinsk
# Processing Record 29 of Set 9 | eyl
# Processing Record 30 of Set 9 | riyadh
# Processing Record 31 of Set 9 | estelle
# Processing Record 32 of Set 9 | marrakesh
# Processing Record 33 of Set 9 | lingyuan
# Processing Record 34 of Set 9 | ouidah
# Processing Record 35 of Set 9 | msanga
# Processing Record 36 of Set 9 | biggar
# Processing Record 37 of Set 9 | launceston
# Processing Record 38 of Set 9 | conceicao do araguaia
# Processing Record 39 of Set 9 | changji
# Processing Record 40 of Set 9 | san quintin
# Processing Record 41 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 9 | college
# Processing Record 43 of Set 9 | zhigansk
# Processing Record 44 of Set 9 | winnetka
# Processing Record 45 of Set 9 | angra
# City not found. Skipping...
# Processing Record 46 of Set 9 | uyutne
# Processing Record 47 of Set 9 | alice town
# Processing Record 48 of Set 9 | bambous virieux
# Processing Record 49 of Set 9 | dukat
# Processing Record 50 of Set 9 | verkhnyaya inta
# Processing Record 1 of Set 10 | port hawkesbury
# Processing Record 2 of Set 10 | manbij
# Processing Record 3 of Set 10 | svatove
# Processing Record 4 of Set 10 | medak
# Processing Record 5 of Set 10 | ust-tsilma
# Processing Record 6 of Set 10 | alta floresta
# Processing Record 7 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 10 | saint anthony
# Processing Record 9 of Set 10 | rio de janeiro
# Processing Record 10 of Set 10 | kayan
# Processing Record 11 of Set 10 | yefimovskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | puerto el triunfo
# Processing Record 13 of Set 10 | ayorou
# Processing Record 14 of Set 10 | crestview
# Processing Record 15 of Set 10 | vallenar
# Processing Record 16 of Set 10 | north bend
# Processing Record 17 of Set 10 | oussouye
# Processing Record 18 of Set 10 | unguia
# Processing Record 19 of Set 10 | sahuaripa
# Processing Record 20 of Set 10 | saint-augustin
# Processing Record 21 of Set 10 | pueblo
# Processing Record 22 of Set 10 | kampot
# Processing Record 23 of Set 10 | iracoubo
# Processing Record 24 of Set 10 | nyurba
# Processing Record 25 of Set 10 | aktau
# Processing Record 26 of Set 10 | jalu
# Processing Record 27 of Set 10 | okoneshnikovo
# Processing Record 28 of Set 10 | monterey
# Processing Record 29 of Set 10 | tangshan
# Processing Record 30 of Set 10 | mae sai
# Processing Record 31 of Set 10 | abu samrah
# Processing Record 32 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 10 | tawang
# Processing Record 34 of Set 10 | makokou
# Processing Record 35 of Set 10 | abu dhabi
# Processing Record 36 of Set 10 | esil
# Processing Record 37 of Set 10 | sosnovoborsk
# Processing Record 38 of Set 10 | kalaleh
# Processing Record 39 of Set 10 | zhangjiakou
# Processing Record 40 of Set 10 | opuwo
# Processing Record 41 of Set 10 | marzuq
# Processing Record 42 of Set 10 | ghanzi
# Processing Record 43 of Set 10 | meulaboh
# Processing Record 44 of Set 10 | farafangana
# Processing Record 45 of Set 10 | ierapetra
# Processing Record 46 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 10 | hobyo
# Processing Record 48 of Set 10 | doka
# Processing Record 49 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 10 | karasburg
# Processing Record 1 of Set 11 | gushikawa
# Processing Record 2 of Set 11 | fort nelson
# Processing Record 3 of Set 11 | kiama
# Processing Record 4 of Set 11 | hailar
# Processing Record 5 of Set 11 | astoria
# Processing Record 6 of Set 11 | chumphon
# Processing Record 7 of Set 11 | oktyabrskiy
# Processing Record 8 of Set 11 | canitas
# City not found. Skipping...
# Processing Record 9 of Set 11 | aklavik
# Processing Record 10 of Set 11 | kanbe
# Processing Record 11 of Set 11 | post falls
# Processing Record 12 of Set 11 | evensk
# Processing Record 13 of Set 11 | lexington park
# Processing Record 14 of Set 11 | pecos
# Processing Record 15 of Set 11 | aljezur
# Processing Record 16 of Set 11 | kabompo
# Processing Record 17 of Set 11 | sechura
# Processing Record 18 of Set 11 | sibu
# Processing Record 19 of Set 11 | doha
# Processing Record 20 of Set 11 | doaba
# Processing Record 21 of Set 11 | ilo
# Processing Record 22 of Set 11 | carutapera
# Processing Record 23 of Set 11 | camacha
# Processing Record 24 of Set 11 | tulun
# Processing Record 25 of Set 11 | huntington
# Processing Record 26 of Set 11 | guadalajara
# Processing Record 27 of Set 11 | kamakura
# Processing Record 28 of Set 11 | cayenne
# Processing Record 29 of Set 11 | ballina
# Processing Record 30 of Set 11 | banjarmasin
# Processing Record 31 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 11 | caravelas
# Processing Record 33 of Set 11 | borisoglebskiy
# Processing Record 34 of Set 11 | ponta delgada
# Processing Record 35 of Set 11 | itarema
# Processing Record 36 of Set 11 | ijui
# Processing Record 37 of Set 11 | winchester
# Processing Record 38 of Set 11 | maumere
# Processing Record 39 of Set 11 | peleduy
# Processing Record 40 of Set 11 | pekan
# Processing Record 41 of Set 11 | buffalo grove
# Processing Record 42 of Set 11 | tucurui
# Processing Record 43 of Set 11 | niteroi
# Processing Record 44 of Set 11 | paamiut
# Processing Record 45 of Set 11 | general roca
# Processing Record 46 of Set 11 | santa helena de goias
# Processing Record 47 of Set 11 | santa cruz
# Processing Record 48 of Set 11 | gat
# Processing Record 49 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 11 | vanimo
# Processing Record 1 of Set 12 | zanjan
# Processing Record 2 of Set 12 | mineros
# Processing Record 3 of Set 12 | beverungen
# Processing Record 4 of Set 12 | gerash
# Processing Record 5 of Set 12 | makung
# City not found. Skipping...
# Processing Record 6 of Set 12 | sabratah
# Processing Record 7 of Set 12 | kankan
# Processing Record 8 of Set 12 | surskoye
# Processing Record 9 of Set 12 | raha
# Processing Record 10 of Set 12 | newport
# Processing Record 11 of Set 12 | la asuncion
# Processing Record 12 of Set 12 | loa janan
# Processing Record 13 of Set 12 | a coruna
# Processing Record 14 of Set 12 | egvekinot
# Processing Record 15 of Set 12 | borsice
# Processing Record 16 of Set 12 | bozoum
# Processing Record 17 of Set 12 | tiberias
# Processing Record 18 of Set 12 | otse
# Processing Record 19 of Set 12 | haines junction
# Processing Record 20 of Set 12 | guasdualito
# Processing Record 21 of Set 12 | auki
# Processing Record 22 of Set 12 | noumea
# Processing Record 23 of Set 12 | persianovskiy
# Processing Record 24 of Set 12 | san cristobal
# Processing Record 25 of Set 12 | mehamn
# Processing Record 26 of Set 12 | flin flon
# Processing Record 27 of Set 12 | karaton
# Processing Record 28 of Set 12 | iqaluit
# Processing Record 29 of Set 12 | yashkul
# Processing Record 30 of Set 12 | comodoro rivadavia
# Processing Record 31 of Set 12 | amalapuram
# Processing Record 32 of Set 12 | galesong
# Processing Record 33 of Set 12 | port pirie
# Processing Record 34 of Set 12 | athabasca
# Processing Record 35 of Set 12 | gotsu
# Processing Record 36 of Set 12 | ilovlya
# Processing Record 37 of Set 12 | aliwal north
# Processing Record 38 of Set 12 | dauphin
# Processing Record 39 of Set 12 | tsogni
# Processing Record 40 of Set 12 | pilani
# Processing Record 41 of Set 12 | santa isabel do rio negro
# Processing Record 42 of Set 12 | nosy varika
# Processing Record 43 of Set 12 | pangody
# Processing Record 44 of Set 12 | nouakchott
# Processing Record 45 of Set 12 | blagoyevo
# Processing Record 46 of Set 12 | kidal
# Processing Record 47 of Set 12 | dalvik
# Processing Record 48 of Set 12 | foz
# Processing Record 49 of Set 12 | srednekolymsk
# Processing Record 50 of Set 12 | ignatovka
# Processing Record 1 of Set 13 | karratha
# Processing Record 2 of Set 13 | tilichiki
# Processing Record 3 of Set 13 | tiznit
# Processing Record 4 of Set 13 | saint-joseph
# Processing Record 5 of Set 13 | kryve ozero
# Processing Record 6 of Set 13 | polunochnoye
# Processing Record 7 of Set 13 | miranda
# Processing Record 8 of Set 13 | siva
# Processing Record 9 of Set 13 | knysna
# Processing Record 10 of Set 13 | ararangua
# Processing Record 11 of Set 13 | caarapo
# Processing Record 12 of Set 13 | chokwe
# Processing Record 13 of Set 13 | qasigiannguit
# Processing Record 14 of Set 13 | odweyne
# Processing Record 15 of Set 13 | shiyan
# Processing Record 16 of Set 13 | olinda
# Processing Record 17 of Set 13 | port keats
# Processing Record 18 of Set 13 | guarapari
# Processing Record 19 of Set 13 | chandler
# Processing Record 20 of Set 13 | lasa
# Processing Record 21 of Set 13 | kralendijk
# Processing Record 22 of Set 13 | slave lake
# Processing Record 23 of Set 13 | ughelli
# Processing Record 24 of Set 13 | sergeyevka
# Processing Record 25 of Set 13 | inhambane
# Processing Record 26 of Set 13 | tukrah
# Processing Record 27 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 13 | chengmai
# City not found. Skipping...
# Processing Record 29 of Set 13 | aktash
# Processing Record 30 of Set 13 | san carlos de bariloche
# Processing Record 31 of Set 13 | boden
# Processing Record 32 of Set 13 | okhotsk
# Processing Record 33 of Set 13 | marsa matruh
# Processing Record 34 of Set 13 | loreto
# Processing Record 35 of Set 13 | bathsheba
# Processing Record 36 of Set 13 | klaksvik
# Processing Record 37 of Set 13 | russell
# Processing Record 38 of Set 13 | dukhovshchina
# Processing Record 39 of Set 13 | cruzilia
# Processing Record 40 of Set 13 | nianzishan
# Processing Record 41 of Set 13 | maracaibo
# Processing Record 42 of Set 13 | villanueva de la serena
# Processing Record 43 of Set 13 | batsfjord
# Processing Record 44 of Set 13 | san policarpo
# Processing Record 45 of Set 13 | mayo
# Processing Record 46 of Set 13 | san andres
# Processing Record 47 of Set 13 | smoky lake
# Processing Record 48 of Set 13 | topolobampo
# Processing Record 49 of Set 13 | banda aceh
# Processing Record 50 of Set 13 | borba
# Processing Record 1 of Set 14 | moranbah
# Processing Record 2 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 3 of Set 14 | coruripe
# Processing Record 4 of Set 14 | luganville
# Processing Record 5 of Set 14 | fort saint james
# Processing Record 6 of Set 14 | soc trang
# Processing Record 7 of Set 14 | la colmena
# Processing Record 8 of Set 14 | okha
# Processing Record 9 of Set 14 | liverpool
# Processing Record 10 of Set 14 | gucheng
# Processing Record 11 of Set 14 | sotuta
# Processing Record 12 of Set 14 | monywa
# Processing Record 13 of Set 14 | winslow
# Processing Record 14 of Set 14 | leningradskiy
# Processing Record 15 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 14 | severo-kurilsk
# Processing Record 17 of Set 14 | altamira
# Processing Record 18 of Set 14 | gomel
# Processing Record 19 of Set 14 | semenivka
# Processing Record 20 of Set 14 | barpali
# Processing Record 21 of Set 14 | waynesville
# Processing Record 22 of Set 14 | arlit
# Processing Record 23 of Set 14 | tokonou
# Processing Record 24 of Set 14 | valdemarpils
# Processing Record 25 of Set 14 | garowe
# Processing Record 26 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 14 | taksimo
# Processing Record 28 of Set 14 | lamu
# Processing Record 29 of Set 14 | zhuhai
# Processing Record 30 of Set 14 | sibolga
# Processing Record 31 of Set 14 | mnogovershinnyy
# Processing Record 32 of Set 14 | gulu
# Processing Record 33 of Set 14 | korsakov
# Processing Record 34 of Set 14 | the valley
# Processing Record 35 of Set 14 | katakwi
# Processing Record 36 of Set 14 | tyrma
# Processing Record 37 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 14 | namibe
# Processing Record 39 of Set 14 | roma
# Processing Record 40 of Set 14 | tabory
# Processing Record 41 of Set 14 | harer
# Processing Record 42 of Set 14 | wanning
# Processing Record 43 of Set 14 | tlapa
# City not found. Skipping...
# Processing Record 44 of Set 14 | rutul
# Processing Record 45 of Set 14 | altay
# Processing Record 46 of Set 14 | dongli
# Processing Record 47 of Set 14 | shunyi
# Processing Record 48 of Set 14 | vagur
# Processing Record 49 of Set 14 | svetlaya
# Processing Record 50 of Set 14 | stromness
# Processing Record 1 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 2 of Set 15 | belyy yar
# Processing Record 3 of Set 15 | xiongyue
# Processing Record 4 of Set 15 | vysha
# Processing Record 5 of Set 15 | bentiu
# Processing Record 6 of Set 15 | russkaya polyana
# Processing Record 7 of Set 15 | asfi
# Processing Record 8 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 15 | kathu
# Processing Record 11 of Set 15 | mar de espanha
# Processing Record 12 of Set 15 | dillon
# Processing Record 13 of Set 15 | fengzhen
# Processing Record 14 of Set 15 | nanakuli
# Processing Record 15 of Set 15 | muros
# Processing Record 16 of Set 15 | alihe
# Processing Record 17 of Set 15 | gobabis
# Processing Record 18 of Set 15 | kilis
# Processing Record 19 of Set 15 | bandarbeyla
# Processing Record 20 of Set 15 | bowen
# Processing Record 21 of Set 15 | andenes
# Processing Record 22 of Set 15 | viedma
# Processing Record 23 of Set 15 | madimba
# Processing Record 24 of Set 15 | malatya
# Processing Record 25 of Set 15 | starovelichkovskaya
# Processing Record 26 of Set 15 | zaysan
# Processing Record 27 of Set 15 | khani
# Processing Record 28 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 15 | osmaniye
# Processing Record 30 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 15 | mount gambier
# Processing Record 32 of Set 15 | beringovskiy
# Processing Record 33 of Set 15 | bettendorf
# Processing Record 34 of Set 15 | batagay-alyta
# Processing Record 35 of Set 15 | werda
# Processing Record 36 of Set 15 | strzegom
# Processing Record 37 of Set 15 | imeni poliny osipenko
# Processing Record 38 of Set 15 | nicoya
# Processing Record 39 of Set 15 | port blair
# Processing Record 40 of Set 15 | dzilam gonzalez
# Processing Record 41 of Set 15 | high level
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Puerto Ayora      EC  -0.7393  -90.3518     72.55        90
# 1             Saint George      US  37.1041 -113.5841     96.64        31
# 2               Coahuayana      MX  18.7333 -103.6833     90.88        55
# 3          Arraial Do Cabo      BR -22.9661  -42.0278     67.86        68
# 4                Jamestown      US  42.0970  -79.2353     70.30        75
# ..                     ...     ...      ...       ...       ...       ...
# 675  Imeni Poliny Osipenko      RU  52.4201  136.4853     50.41        94
# 676                 Nicoya      CR  10.1483  -85.4520     89.15        76
# 677             Port Blair      IN  11.6667   92.7500     81.81        81
# 678        Dzilam Gonzalez      MX  21.2833  -88.9333     84.85        69
# 679             High Level      CA  58.5169 -117.1360     91.80        31
#
#      Cloudiness  Wind Speed       Description
# 0            48        7.00  scattered clouds
# 1             1        4.00         clear sky
# 2             6        5.35         clear sky
# 3            20       13.80        few clouds
# 4            75        4.00     broken clouds
# ..          ...         ...               ...
# 675          99        0.36   overcast clouds
# 676          97        7.56   overcast clouds
# 677         100       18.90   overcast clouds
# 678          84       10.25     broken clouds
# 679           0        2.51         clear sky
#
# [680 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
